# %%
import requests
import bs4

# %%
res = requests.get('https://www.ft.com/bitcoin')

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

def get_bitcoin_news(url):
    # Send an HTTP request to the webpage
    res = requests.get(url)

    # Check if the request was successful
    if res.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(res.text, 'html.parser')
        
        # Find all headlines related to Bitcoin
        headlines = soup.select('.o-teaser__heading')
        subheadlines = soup.select('.js-teaser-standf_newsirst-link')
        dates = soup.select('.o-date')

        # Create lists to store extracted data
        headlines_list = []
        subheadlines_list = []
        dates_list = []

        # Iterate over each headline, subheadline, and date
        for headline, subheadline, date in zip(headlines, subheadlines, dates):
            # Extract the text from the headline, subheadline, and date elements
            headline_text = headline.text.strip()
            subheadline_text = subheadline.text.strip()
            date_text = date.text.strip()

            # Parse the date string with multiple formats
            date_obj = None
            date_formats = ["%A, %d %B, %Y", "%d %B %Y"]
            for date_format in date_formats:
                try:
                    date_obj = datetime.strptime(date_text, date_format)
                    break
                except ValueError:
                    continue

            if date_obj is None:
                print(f"Date format not recognized for date: {date_text}")
                continue

            # Append the extracted data to lists
            headlines_list.append(headline_text)
            subheadlines_list.append(subheadline_text)
            dates_list.append(date_obj)

        # Create DataFrame from the lists
        df_news = pd.DataFrame({'Date': dates_list, 'Headline': headlines_list, 'Subheadline': subheadlines_list})

        # Sort DataFrame by 'Date'
        df_news = df_news.sort_values(by='Date')

        # Reset index
        df_news.reset_index(drop=True, inplace=True)

        return df_news
    else:
        print(f"Failed to retrieve the page. Status code: {res.status_code}")
        return None

# Usage
url = 'https://www.ft.com/bitcoin'
bitcoin_headlines_df_news = get_bitcoin_news(url)

# Print the DataFrame
if bitcoin_headlines_df_news is not None:
    print(bitcoin_headlines_df_news)
# Out:
# Empty DataFrame
# Columns: [Date, Headline, Subheadline]
# Index: []

# %%
df
# Out:
#          Date                                           Headline  \
# 0  2024-04-08  Terraform Labs and Do Kwon found liable for fr...
# 1  2024-04-11                  Speak your brains: crypto edition
# 2  2024-04-12                      Welcome to crypto archipelago
# 3  2024-04-12  Should UK investors have easier access to crypto?
# 4  2024-04-16  Bitcoin helps power BlackRock assets under man...
# 5  2024-04-18     Bitcoin’s halving makes its future pay-to-play
# 6  2024-04-19    Crypto miners hoard bitcoin as supply cut looms
# 7  2024-04-29              Miners double down on bitcoin halving
# 8  2024-04-30  Vomiting frogs and other ‘dust’ prove vexing f...
# 9  2024-05-03             Hong Kong joins global crypto ETF race
# 10 2024-05-08  Cryptofinance: Stablecoins encroach on shadow ...
# 11 2024-05-10  FTX account holders will get their money back ...
# 12 2024-05-13  Cryptofinance: The trade-offs in chasing the d...
# ...
